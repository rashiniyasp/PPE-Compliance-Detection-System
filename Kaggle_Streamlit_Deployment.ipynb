# %% [markdown]
# # PPE Compliance Detection - Kaggle GPU Streamlit Deployment
#
# This notebook runs the Streamlit app on a Kaggle GPU instance and uses `localtunnel` to expose it to the public internet.

# %%
# 1. Clone the repository and pull Git LFS files (model weights)
# !git clone https://github.com/rashiniyasp/PPE-Compliance-Detection-System.git
# %cd PPE-Compliance-Detection-System
# !git lfs pull

# %%
# 2. Install Python dependencies and Node.js localtunnel
# !pip install -r requirements.txt
# !npm install -g localtunnel

# %%
# 3. Start the Streamlit app in the background
# !nohup streamlit run app.py &> logs.txt &

# %%
# 4. Get the Tunnel Password (IP Address)
# IMPORTANT: Copy the IP address printed by this cell. 
# You will need to paste it into the localtunnel warning page.
import urllib.request
print("COPY THIS IP ADDRESS FOR THE TUNNEL PASSWORD:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))

# %%
# 5. Expose the Streamlit port (8501) to the internet
# Click the url generated (e.g., https://your-url.loca.lt)
# !npx localtunnel --port 8501
